# %%
import scipy
import numpy as np
from sklearn.neighbors import KernelDensity
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import estimate_bandwidth
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.preprocessing import scale

import pandas as pd

from scipy import stats
from scipy.stats import beta
from math import sin
from random import randint

import matplotlib.pyplot as plt
import itertools as it
from itertools import product

from _plotly_future_ import v4_subplots
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import *
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
init_notebook_mode(connected=True)

import collections

def recursively_default_dict():
        return collections.defaultdict(recursively_default_dict)

from matplotlib.collections import BrokenBarHCollection
import re

import gzip

import tempfile

from structure_tools.Modules_tools import return_fsts

PCA_color_ref= ['darkseagreen','crimson', 'darkorange', 'darkblue', 'darkcyan',
            'darkgoldenrod', 'darkgray', 'darkgrey', 'darkgreen',
            'darkkhaki', 'darkmagenta', 'darkolivegreen', 'darkorange',
            'darkorchid', 'darkred', 'darksalmon', 'darkseagreen',
            'darkslateblue', 'darkslategray', 'darkslategrey',
            'darkturquoise', 'darkviolet', 'deeppink']
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Read VCF

# %%
from structure_tools.vcf_geno_tools import read_geno_nanumv2

Home= 'vcf/'

Chr= '8'

'''
start= '3000000'
end= '5000000'
filename= Home + 'chrchr{}.{}-{}.chr{}.vcf.gz'.format(Chr,start,end,Chr)
'''

filename= Home + 'Gravel_output_fasta.vcf.gz'
start= 0
end= 1000000

row_info= 6
header_info= 9
phased= False


genotype, summary, Names= read_geno_nanumv2(filename, header_info= header_info,phased= phased)

print('Number of markers: {}'.format(genotype.shape[1]))
print('Number of individuals: {}'.format(genotype.shape[0]))
summary.head()
# Out:
# Number of markers: 5195
# Number of individuals: 530
#   CHROM   POS ID REF ALT  QUAL FILTER                 INFO FORMAT
# 0     1   122  .   C   T  1000   PASS    AC=1;DP=1000;AA=C     GT
# 1     1   231  .   C   G  1000   PASS  AC=649;DP=1000;AA=C     GT
# 2     1   420  .   T   C  1000   PASS   AC=48;DP=1000;AA=T     GT
# 3     1   669  .   C   A  1000   PASS    AC=2;DP=1000;AA=C     GT
# 4     1  1095  .   T   A  1000   PASS   AC=28;DP=1000;AA=T     GT

# %% [markdown]
# ## Read fasta

# %%
from fasta_utilities import (
    reference_sequence, get_mutations, get_by_path, 
    set_by_path, fasta_get_freq, get_complement,
    complement_dicts,collapse_freqs, kmer_dict_init,
    vcf_kmers, geno_kmers, vcf_muts_matrix,
    geno_muts_v2, kmer_comp_index, kmer_mut_index
)

# %%
dir_fasta= '/mnt/d/GitHub/fine-scale-mutation-spectrum-master/Subset_explore/data/'
chrom= '1'
reference= 'hg19'

'''
refseq= reference_sequence(chrom,reference,dir_launch= dir_fasta)
refseq= refseq.decode()
'''

fasta_file= dir_fasta + 'MBfasta_chr22.MB18-19.fa'

with open(fasta_file,'r') as f:
    lines= f.readlines()

refseq= lines[1].strip()

# %% [markdown]
# > get mutation indicies.

# %%
sampleSizes= [216,108,206]
pop_Names= ['Af','Eu','Ea']
popLabels= np.repeat(range(len(sampleSizes)), sampleSizes)
indices= {
    z: [x for x in range(len(popLabels)) if popLabels[x] == z] for z in list(set(popLabels))
}

# %% [markdown]
# RIP

# %% [raw]
# '''
# ## In memory of geno_muts_v1
#
# from fasta_utilities import (
#     kmer_mut_init,
#     vcf_muts, kmer_comp_index, collapse_muts,
#     geno_muts_v1
# )
#
# ## fasta lib
# kmer_dict= fasta_get_freq(refseq,start= int(wstart),end= int(wend),step= 1,ksize=ksize,bases= bases)
# comp_dict, comp_index= complement_dicts(bases= bases,ksize= ksize)
# collapsed_freqs= collapse_freqs(dict(kmer_dict),comp_index)
# collapsed_freqs= np.array(collapsed_freqs) / sum(collapsed_freqs)
#
# ##
# ind_collapsed_freqs= geno_kmers(Window, subset_summary, refseq, comp_index,
#                                 start= wstart, end= wend, ksize= ksize , bases= bases)
# ##
# vcf_muts_vector= vcf_muts(refseq,subset_summary,start= wstart,end= wend,ksize= ksize,bases=bases)
# ind_collapsed_muts= geno_muts_v1(Window, kmer_dict, vcf_muts_vector,mutations,
#                                  bases= bases, ksize= ksize, Wl= Wlen, collapse= collapsed)
#
# '''

# %% [markdown]
# ### Window analysis
#
# Estimate mutation profile at local genomic window. Determine using `wstart` and `wend`.
#
# Chose kmer size to construct profile with using `ksize` (int) and weather to collapse complementary mutations using `collapsed` (boolean).

# %%
### Start playing

wstart= int(start) + 0
wend= wstart + 50000
Wlen= wend - wstart
ksize= 3 # odd.
bases = 'ACGT'
collapsed= True

genotype_parse= [x for x in range(summary.shape[0]) if int(summary.POS[x])-1 >= wstart and int(summary.POS[x])-1 <= wend]
Window= genotype[:,genotype_parse]
subset_summary= summary.loc[genotype_parse,:].reset_index()

print(Window.shape)

##
mut_matrix= vcf_muts_matrix(refseq,subset_summary,start= wstart,end= wend,ksize= ksize,bases=bases, collapse= collapsed)
ind_collapsed_mat= geno_muts_v2(np.array(Window), mut_matrix)
ind_collapsed_mat.shape
# Out:
# (530, 234)
# (530, 96)

# %%
Window.shape
# Out:
# (530, 234)

# %%
mut_matrix.shape
# Out:
# (96, 234)

# %%
testi= 62
test_gen= Window[testi,:]
test_mat= ind_collapsed_mat[testi,:]
print(sum(test_gen))
print(sum(test_mat))
# Out:
# 34
# 34.0

# %% [markdown]
# > Principal component analysis of individual mutation spectrums.

# %%
from sklearn.decomposition import PCA
n_comp= 3

pca = PCA(n_components=n_comp, whiten=False,svd_solver='randomized')
features = pca.fit_transform(Window)

var_comps= pca.explained_variance_ratio_

# %%
from plotly.subplots import make_subplots
from plotly import tools

titles= ['PC1-2','PC1-3']
fig_subplots = tools.make_subplots(rows= 1, cols=2,
                             subplot_titles=tuple(titles))

for col in range(1,3):
    fig_data= [go.Scatter(
            x= features[indices[i],0],
            y= features[indices[i],col],
            mode= "markers",
            marker= {
            'line': {'width': 1},
            'size': 8,
            'symbol': 'circle',
          "opacity": 1
          },
          name= pop_Names[i]
        ) for i in list(indices.keys())]
    
    for trace1 in fig_data:
        fig_subplots.append_trace(trace1, 1, col)
    
    fig_subplots.update_xaxes(title= 'PC1')

    fig_subplots.update_yaxes(title= 'PC' + str(col + 1),row=1, col=col)


layout = go.Layout(
    title= 'mutation profile PCA'
)


fig = go.Figure(data=fig_subplots, layout=layout)
fig['layout'].update(title= 'individuals')
iplot(fig)
# Out:
# /home/floyd/.local/lib/python3.6/site-packages/plotly/tools.py:465: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# <div>
#
#
#             <div id="84726a51-52ef-4106-b40f-8690f5e0335f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById
3.090919924475045, -3.137943139943944, -2.846952883587027, -1.6739024892283991, -1.5895102764983244, -3.029693620193228, 1.5625000144113501, -0.9617454978701081, 0.27651482870912125, -1.4723985615974837, -2.3762819961202166, -1.8333425027806325, -1.66309514762226, -1.4463983487946264, -1.36986489913141, -3.0847216271252647, -0.33958842268556494, -1.641007301557253, -1.720820207199856, -1.7180005708133643, -1.2820021892247146, -2.7762587803282344, -1.5470650925997818, 0.11403668466773433, -0.5215089252190326, -2.178525445324933, -2.0087983042046904, -1.5297649528802748, -1.5100213209295303, -1.1641720627264351, -1.2787760740055933, 0.12572176524147458, -1.7841354610137203, 1.239721969215405, -1.200870376654333, -1.527321460649037, 0.80218127206043, -0.0536961494383899, -1.425952439686372, -0.0003669544830633734, -1.125110669638951, -0.9620041178007025, -1.5296617708702833, 0.45407788511884883, -1.5768371244418624, -2.846952883587027, -0.2019043506219578, -1.5100213209295303, -2.8945006381275262, -3.1258138795631623, ...

# %%
from sklearn.cluster import MeanShift, estimate_bandwidth

bandwidth = estimate_bandwidth(features, quantile=0.3, n_samples=features.shape[0])

ms = MeanShift(bandwidth=bandwidth, bin_seeding=False)
ms.fit(features)
labels = ms.labels_
zlib= {
    z: [x for x in range(len(labels)) if labels[x] == z] for z in list(set(labels))
}

titles= ['PC1-2','PC1-3']
fig_subplots = tools.make_subplots(rows= 1, cols=2,
                             subplot_titles=tuple(titles))

for col in range(1,3):
    fig_data= [go.Scatter(
            x= features[zlib[i],0],
            y= features[zlib[i],col],
            mode= "markers",
            marker= {
            'line': {'width': 1},
            'size': 8,
            'symbol': 'circle',
          "opacity": 1
          },
          name= str(i)
        ) for i in list(zlib.keys())]
    
    for trace1 in fig_data:
        fig_subplots.append_trace(trace1, 1, col)
    
    fig_subplots.update_xaxes(title= 'PC1')

    fig_subplots.update_yaxes(title= 'PC' + str(col + 1),row=1, col=col)


layout = go.Layout(
    title= 'mutation profile PCA'
)


fig = go.Figure(data=fig_subplots, layout=layout)
fig['layout'].update(title= 'individuals')
iplot(fig)
# Out:
# /home/floyd/.local/lib/python3.6/site-packages/plotly/tools.py:465: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# <div>
#
#
#             <div id="95dd5fae-816f-443c-8f93-ced7850950b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("95dd5fae-816f-443c-8f93-ced7850950b5")) {
#                     Plotly.newPlot(
#                         '95dd5fae-816f-443c-8f93-ced7850950b5',
#                         [{"marker": {"line": {"width": 1}, "opacity": 1, "size": 8, "symbol": "circle"}, "mode": "markers", "name": "0", "type": "scatter", "x": [-1.414981989757623, -3.0769843966935606, -1.5878737217300694, -1.2856947299822667, -1.2939433942674947, -2.7194753401545593, -2.97965571221109, -3.2257094441361684, -3.0607477609334834, 0.23009095022000353, -1.1236016209641404, -1.3064263140820094, -2.9869249182996445, -1.36986489913141, -3.1622027911682453, -1.4078813443167721, -2.7357557460660002, -3.2257094441361684, 0.626387993715869, -2.9593158880941717, -2.948407913821791, -2.70846053884491, -1.2545796958284214, -2.826156108254506, -3.078749760693764, -2.650745658237203, -1.4721684735080949, -2.
mutations= get_mutations(bases= bases,ksize= ksize)
kmers, kmer_idx= kmer_comp_index(mutations)

mut_list= ['_'.join(x) for x in kmer_idx.values()]
#mut_list= ['_'.join(x) for x in mutations]

mut_indices= {
    z:[x for x in range(len(mut_list)) if mut_list[x][int(ksize / 2)] in z] for z in ['AT','CG']
}

col_mut= {
    'AT': 'blue',
    'CG': 'red'
}

n_comp= 3

pca = PCA(n_components=n_comp, whiten=False,svd_solver='randomized')
Comps = pca.fit_transform(ind_collapsed_mat.T)

var_comps= pca.explained_variance_ratio_

titles= ['PC1-2','PC1-3']
fig_subplots = tools.make_subplots(rows= 1, cols=2,
                             subplot_titles=tuple(titles))

for col in range(1,3):
    fig_data= [go.Scatter(
            x= Comps[mut_indices[i],0],
            y= Comps[mut_indices[i],col],
            mode= "markers",
            text= [mut_list[x] for x in mut_indices[i]],
            marker= {
            'color': col_mut[i],
            'line': {'width': 1},
            'size': 8,
            'symbol': 'circle',
          "opacity": 1
          },
            name= i
        ) for i in list(mut_indices.keys())]
    
    for trace1 in fig_data:
        fig_subplots.append_trace(trace1, 1, col)
        
    fig_subplots.update_xaxes(title= 'PC1')

    fig_subplots.update_yaxes(title= 'PC' + str(col + 1),row=1, col=col)


layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    ),
    yaxis=dict(
        title='PC2: {}'.format(round(var_comps[1],3))),
    xaxis=dict(
    title= 'PC1: {}'.format(round(var_comps[0],3)))
)


fig = go.Figure(data=fig_subplots, layout=layout)
fig['layout'].update(title= 'kmers')
iplot(fig)
# Out:
# /home/floyd/.local/lib/python3.6/site-packages/plotly/tools.py:465: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# <div>
#
#
#             <div id="49805f1d-ab29-4503-8131-42b685691d2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("49805f1d-ab29-4503-8131-42b685691d2e")) {
#                     Plotly.newPlot(
#                         '49805f1d-ab29-4503-8131-42b685691d2e',
#                         [{"marker": {"color": "blue", "line": {"width": 1}, "opacity": 1, "size": 8, "symbol": "circle"}, "mode": "markers", "name": "AT", "text": ["AAAC_TTTG", "AAAG_TTTC", "AAAT_TTTA", "AACC_GTTG", "AACG_GTTC", "AACT_GTTA", "AAGC_CTTG", "AAGG_CTTC", "AAGT_CTTA", "AATC_ATTG", "AATG_ATTC", "AATT_ATTA", "ATAA_TATT", "ATAC_TATG", "ATAG_TATC", "ATCA_GATT", "ATCC_GATG", "ATCG_GATC", "ATGA_CATT", "ATGC_CATG", "ATGG_CATC", "CAAC_TTGG", "CAAG_TTGC", "CAAT_TTGA", "CACC_GTGG", "CACG_GTGC", "CACT_GTGA", "CAGC_CTGG", "CAGG_CTGC", "CAGT_CTGA", "CTAA_TAGT", "CTAC_TAGG", "CTAG_TAGC", "CTCA_GAGT", "CTCC_GAGG", "CTCG_GAGC", "GAAC_TTCG", "GAAG_TTCC", "GAAT_TTCA", "GACC_GTCG", "GACG_GTCC", "GACT_GTCA", "GTAA_TACT", "GTAC_TACG", "GTAG_TACC", "TAAC_TTAG", "TAAG_TTAC", "TAAT_TTAA"], "type": "scatter", "x": [1.0687735719359377, 1.3140425144362327, 1.642182445481305, 0.8727922516336731, -0.08894575792585153, -0.16
# %% [markdown]
# ### Across windows

# %% [markdown]
# > i. Estimate kmer mutation profiles at each window, cluster, draw average of mean shift clusters.

# %%
Wlen= 1e4
ksize= 3
n_comp= 4

Nl= 200
start_list= np.random.uniform(int(start),int(end) - Wlen,Nl)
start_list= np.array(start_list,dtype= int)
#start_list= np.arange(int(start),int(end) - Wlen,1e4)
comp_dict, comp_index= complement_dicts(bases= bases,ksize= ksize)

window_muts= []
window_list= []

for wstart in start_list:
    wstart= int(wstart)
    wend= wstart + Wlen 

    genotype_parse= [x for x in range(summary.shape[0]) if int(summary.POS[x]) - 1 >= wstart and int(summary.POS[x]) - 1 <= wend]
    Window= genotype[:,genotype_parse]
    subset_summary= summary.loc[genotype_parse,:].reset_index()
    
    if Window.shape[1] > 10:
        ####
        ####
        mut_matrix= vcf_muts_matrix(refseq,subset_summary,start= wstart,end= wend,ksize= ksize,bases=bases)
        ind_collapsed_mat= geno_muts_v2(np.array(Window), mut_matrix)

        
        #ind_collapsed_muts= scale(ind_collapsed_muts)
        ind_collapsed_muts= np.nan_to_num(ind_collapsed_mat)
        pca = PCA(n_components=n_comp, whiten=False,svd_solver='randomized')
        features = pca.fit_transform(scale(ind_collapsed_muts))

        bandwidth = estimate_bandwidth(features, quantile=0.2, n_samples=features.shape[0])
        
        ms = MeanShift(bandwidth=bandwidth, bin_seeding=False)
        ms.fit(features)
        labels = ms.labels_
        
        zlib= {
            z: [x for x in range(len(labels)) if labels[x] == z] for z in list(set(labels))
        }
        
        average_muts= [np.mean(ind_collapsed_muts[zlib[i]],axis= 0) for i in zlib.keys()]
        
        window_list.extend([wstart] * len(zlib))
        window_muts.extend(average_muts)


window_muts= np.array(window_muts)
print(window_muts.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-98f8657d2d05> in <module>
#      23         ####
#      24         ####
# ---> 25         mut_matrix= vcf_muts_matrix(refseq,subset_summary,start= wstart,end= wend,ksize= ksize,bases=bases)
#      26         ind_collapsed_mat= geno_muts_v2(np.array(Window), mut_matrix)
#      27
#
# D:\GitHub\fine-scale-mutation-spectrum-master\Subset_explore\fasta_utilities.py in vcf_muts_matrix(refseq, summary, start, end, ksize, bases, collapse)
#     384
#     385             if collapse:
# --> 386                 mut_index= kmers[mut]
#     387                 mut_array=np.zeros(len(kmer_idx))
#     388             else:
#
# KeyError: 'TTGC,G'

# %% [markdown]
# > ii. Compare average vectors across windows using PCA again.

# %%
n_comp= 3

subsel= list(np.random.choice(list(range(window_muts.shape[0])),890,replace= False))

data= scale(window_muts[subsel])
pca = PCA(n_components=n_comp, whiten=False,svd_solver='randomized')
features = pca.fit_transform(data)

var_comps= pca.explained_variance_ratio_

####

from sklearn.cluster import MeanShift, estimate_bandwidth
bandwidth = estimate_bandwidth(features, quantile=0.3, n_samples=features.shape[0])

ms = MeanShift(bandwidth=bandwidth, bin_seeding=False)
ms.fit(features)
labels = ms.labels_
'''

###

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=0).fit(features)
labels= kmeans.labels_
'''
###
zlib= {
    z: [x for x in range(len(labels)) if labels[x] == z] for z in list(set(labels))
}

zlib= {z:g for z,g in zlib.items() if len(g) > 1}

titles= ['PC1-2','PC1-3']
fig_subplots = tools.make_subplots(rows= 1, cols=2,
                             subplot_titles=tuple(titles))

for col in range(1,3):
    fig_data= [go.Scatter(
            x= features[zlib[i],0],
            y= features[zlib[i],col],
            mode= "markers",
            marker= {
            'line': {'width': 1},
            'size': 8,
            'symbol': 'circle',
          "opacity": 1
          },
          name= str(i)
        ) for i in list(zlib.keys())]
    
    for trace1 in fig_data:
        fig_subplots.append_trace(trace1, 1, col)
    
    fig_subplots.update_xaxes(title= 'PC1')

    fig_subplots.update_yaxes(title= 'PC' + str(col + 1),row=1, col=col)


layout = go.Layout(
    title= 'mutation profile PCA'
)


fig = go.Figure(data=fig_subplots, layout=layout)
fig['layout'].update(title= 'individuals')
iplot(fig)
# Out:
# <div>
#
#
#             <div id="404bee49-5e0d-4ed7-83d3-caafc1dc7d56" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("404bee49-5e0d-4ed7-83d3-caafc1dc7d56")) {
#                     Plotly.newPlot(
#                         '404bee49-5e0d-4ed7-83d3-caafc1dc7d56',
#                         [{"marker": {"line": {"width": 1}, "opacity": 1, "size": 8, "symbol": "circle"}, "mode": "markers", "name": "0", "type": "scatter", "uid": "8cddfabe-650e-45fc-90ad-e5d3fc60b019", "x": [-0.13055804305539703, 1.4052335218009313, -1.8696837045830492, 0.31769986619886637, -5.002688940122433, 0.8294557135811016, 0.8459917379058779, 1.2267496915911043, -1.1249034384894783, -2.5913795087878904, 0.7242757135767203, -1.098110924279301, -0.7129045950667157, -0.6984943009018829, 0.699860696633937, 0.6023388828073017, -0.22286371846920613, 0.5016094594634225, 2.736228614645329, 0.11332861180508608, 1.7792855306101967, -2.856369517682084, 1.15992680051894, 1.8108804842373682, -0.29650315606355604, -1.0239680626908834, -0.1589041033333103, -2.2687765646832467, -1.994997176953921, -0.05302572882530922, -1.5520349026520506, 0.620195791361628, 2.5062394512436152, 0.5528952667038997, -0.6955087359381676, 0.15075408775850047, 0.5102316668439089, -1.2490377555943266, 1.1658948890377547, -3.023035336159767, -0.5740657853699896, -3.0361820325648874, 1.6177492656108956, -0.6851726101330207, -1.445920311104324, 0.24250945951415415, 0.2734290828257215, -1.0188074134872167, -0.8890698702009292, -0.3908570359468857, 0.3432270850210333, 1.14397717898758, -0.7970916679916649, 1.7960200771979378, -2.133272686021118, 2.1595389465549037, -0.4578312776958708, -0.7724835148752003, -2.0444104630233717, 0.22248051664873836, -1.7157254988676267, 2.3565123942103448, -0.3950691669637852, -0.6086582079214022, -0.27204711303819523, 0.48689747839275577, 0.49284805877347765, -1.3798870201570863, -0.32121257278760473, 0.33487627130803455, -1.622158738011193, 1.2900861223429605, -3.728462199302948, -0.3995759831218965, 1.0224406782717035, -0.3507505855650292, 0.7278565077421285, 0.10302984736003004, -0.005707440560639295, -0.7284767100615733, 2.156255299797598, -0.9456322200854137, 1.5983220861252996, -3.3834023776976507, 0.017672086136522564, -0.6119050465769857, 0.2107276611702972, -0.11524646191259424, 0.59983944835415, 0.15439195685249993, -0.9373037962972401, 0.49336977815990574, -0.5816883124614565, 0.9836486170911233, 2.
214948, 3214948, 3214948, 3880363, 3880363, 3880363, 3880363, 4014392, 4014392, 3574034, 3574034, 3574034, 3574034, 3574034, 3574034, 3574034, 3574034, 4270431, 4270431, 4270431, 4270431, 4270431, 4959134, 4959134, 4959134, 4959134, 4959134, 4959134, 4959134, 4959134, 4686702, 4686702, 4686702, 4686702, 3250797, 3250797, 3250797, 3250797, 3250797, 4478928, 4478928, 4478928, 4478928 ...

# %% [markdown]
# > iv. PCA on transposed matrix - kmers

# %%
from sklearn.decomposition import PCA
mutations= get_mutations(bases= bases,ksize= ksize)
kmers, kmer_idx= kmer_comp_index(mutations)

mut_list= ['_'.join(x) for x in kmer_idx.values()]

mut_indices= {
    z:[x for x in range(len(mut_list)) if mut_list[x][int(ksize / 2)]  in z] for z in ['AT','CG']
}

col_mut= {
    'AT': 'blue',
    'CG': 'red'
}

n_comp= 3

pca = PCA(n_components=n_comp, whiten=False,svd_solver='randomized')
Comps = pca.fit_transform(window_muts.T)

var_comps= pca.explained_variance_ratio_

titles= ['PC1-2','PC1-3']
fig_subplots = tools.make_subplots(rows= 1, cols=2,
                             subplot_titles=tuple(titles))

for col in range(1,3):
    fig_data= [go.Scatter(
            x= Comps[mut_indices[i],0],
            y= Comps[mut_indices[i],col],
            mode= "markers",
            text= [mut_list[x] for x in mut_indices[i]],
            marker= {
            'color': col_mut[i],
            'line': {'width': 1},
            'size': 8,
            'symbol': 'circle',
          "opacity": 1
          },
            name= i
        ) for i in list(mut_indices.keys())]
    
    for trace1 in fig_data:
        fig_subplots.append_trace(trace1, 1, col)
        
    fig_subplots.update_xaxes(title= 'PC1')

    fig_subplots.update_yaxes(title= 'PC' + str(col + 1),row=1, col=col)


layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    ),
    yaxis=dict(
        title='PC2: {}'.format(round(var_comps[1],3))),
    xaxis=dict(
    title= 'PC1: {}'.format(round(var_comps[0],3)))
)


fig = go.Figure(data=fig_subplots, layout=layout)
fig['layout'].update(title= 'kmers')
iplot(fig)
# Out:
# <div>
#
#
#             <div id="41bac2b5-0ff9-403a-92d1-33d9de58e5a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("41bac2b5-0ff9-403a-92d1-33d9de58e5a0")) {
#                     Plotly.newPlot(
#                         '41bac2b5-0ff9-403a-92d1-33d9de58e5a0',
#                         [{"marker": {"color": "blue", "line": {"width": 1}, "opacity": 1, "size": 8, "symbol": "circle"}, "mode": "markers", "name": "AT", "text": ["AAAAAC_TTTTTG", "AAAAAG_TTTTTC", "AAAAAT_TTTTTA", "AAAACC_GTTTTG", "AAAACG_GTTTTC", "AAAACT_GTTTTA", "AAAAGC_CTTTTG", "AAAAGG_CTTTTC", "AAAAGT_CTTTTA", "AAAATC_ATTTTG", "AAAATG_ATTTTC", "AAAATT_ATTTTA", "AAACAC_TGTTTG", "AAACAG_TGTTTC", "AAACAT_TGTTTA", "AAACCC_GGTTTG", "AAACCG_GGTTTC", "AAACCT_GGTTTA", "AAACGC_CGTTTG", "AAACGG_CGTTTC", "AAACGT_CGTTTA", "AAACTC_AGTTTG", "AAACTG_AGTTTC", "AAACTT
_TTAGTT", "ACTAAC_TTAGTG", "ACTAAG_TTAGTC", "ACTACA_GTAGTT", "ACTACC_GTAGTG", "ACTACG_GTAGTC", "ACTAGA_CTAGTT", "ACTAGC_CTAGTG", "ACTAGG_CTAGTC", "ACTATA_ATAGTT", "ACTATC_ATAGTG", "ACTATG_ATAGTC", "ACTCAA_TGAGTT", "ACTCAC_TGAGTG", "ACTCAG_TGAGTC", "ACTCCA_GGAGTT", "ACTCCC_GGAGTG", "ACTCCG_GGAGTC", "ACTCGA_CGAGTT", "ACTCGC_CGAGTG", "ACTCGG_CGAGTC", "ACTCTA_AGAGTT", "ACTCTC_AGAGTG", "ACTCTG_AGAGTC", "ACTGAA_TCAGTT", "ACTGAC_TCAGTG", "ACTGAG_TCAGTC", "ACTGCA_GCAGTT", "ACTGCC_GCAGTG", "ACTGCG_GCAGTC", "ACTGGA_CCAGTT", "ACTGGC_CCAGTG", "ACTGGG_CCAGTC", "ACTTAA_TAAGTT", "ACTTAC_TAAGTG", "ACTTAG_TAAGTC", "ACTTCA_GAAGTT", "ACTTCC_GAAGTG", "ACTTCG_GAAGTC", "ACTTGA_CAAGTT", "ACTTGC_CAAGTG", "ACTTGG_CAAGTC", "AGAAAC_TTTCTG", "AGAAAG_TTTCTC", "AGAAAT_TTTCTA", "AGAACC_GTTCTG", "AGAACG_GTTCTC", "AGAACT_GTTCTA", "AGAAGC_CTTCTG", "AGAAGG_CTTCTC", "AGAAGT_CTTCTA", "AGAATC_ATTCTG", "AGAATG_ATTCTC", "AGAATT_ATTCTA", "AGACAC_TGTCTG", "AGACAG_TGTCTC", "AGACAT_TGTCTA", "AGACCC_GGTCTG", "AGACCG_GGTCTC", "AGACCT_GGTCTA", "AGACGC_CGTCTG", "AGACGG_CGTCTC", "AGACGT_CGTCTA", "AGACTC_AGTCTG", "AGACTG_AGTCTC", "AGACTT_AGTCTA", "AGAGAC_TCTCTG", "AGAGAG_TCTCTC", "AGAGAT_TCTCTA", "AGAGCC_GCTCTG", "AGAGCG_GCTCTC", "AGAGCT_GCTCTA", "AGAGGC_CCTCTG", "AGAGGG_CCTCTC", "AGAGGT_CCTCTA", "AGATAC_TATCTG", "AGATAG_TATCTC", "AGATAT_TATCTA", "AGATCC_GATCTG", "AGATCG_GATCTC", "AGATCT_GATCTA", "AGATGC_CATCTG", "AGATGG_CATCTC", "AGATGT_CATCTA", "AGTAAA_TTACTT", "AGTAAC_TTACTG", "AGTAAG_TTACTC", "AGTACA_GTA ...

# %% [markdown]
# ### Mutation type distribution

# %%
def kmer_mut_init(mutations, default_this= 0):
    '''produce nested dictionary of nucs for a particular kmer size'''
    
    mut_lib= recursively_default_dict()
    
    d= 0
    for mut in range(len(mutations)):
        trimer= mutations[mut]
        trimer= ''.join(trimer)
        get_by_path(mut_lib, trimer[:-1])[trimer[-1]]= default_this
    
    return mut_lib


def vcf_muts_pos(refseq,summary,start= 0,end= 0,ksize= 3):
    ''' 
    Return matrix of mutation contexts by SNP in genotype array
    Each mutation is mapped to list of possible mutations as a binary vector.
    '''
    kmer_dict= kmer_mut_init(mutations,default_this= '')
    
    if end == 0:
        end= max(summary.POS)
    
    k5= int(ksize/2)
    k3= ksize - k5
    pos_mut= []
    
    for x in range(summary.shape[0]):
        pos= int(summary.POS[x]) - 1
        if pos >=  start and pos <= end:
            kmer= refseq[pos-k5: pos + k3]
            mut= kmer + summary.ALT[x]
            
            get_by_path(kmer_dict, mut[:-1])[mut[-1]] += '.' + str(pos)
    
    
    return kmer_dict

# %%
wstart= int(start) + 1e5
wend= wstart + 1.5e6
ksize= 3 # odd.
bases = 'ACGT'

mutations= get_mutations(bases= bases,ksize= ksize)

mut_positions= vcf_muts_pos(refseq,summary,start= wstart,end= wend,ksize= ksize)

###
kmer_select= {
    0: ['C'],
    1: ['C'],
    2: ['C']
}

mut_list= [''.join(x) for x in mutations]
mutat= [x for x in mut_list if sum([x[e] in kmer_select[e] for e in kmer_select.keys()]) == len(kmer_select)]
mutat= ['CAAG','TTGC','CCGG','CGGC']


positions= [get_by_path(mut_positions, list(x)) for x in mutat]
positions= [[y for y in x.split('.') if len(y)] for x in positions]
positions= [np.array(y,dtype= int) for y in positions]
labels= mutat

'''
positions= [list(it.chain(*positions))]
labels= [''.join([str(v),str(''.join(g))]) for v,g in kmer_select.items()]
labels= ['/'.join(labels)]
'''
# Out:
# "\npositions= [list(it.chain(*positions))]\nlabels= [''.join([str(v),str(''.join(g))]) for v,g in kmer_select.items()]\nlabels= ['/'.join(labels)]\n"

# %%
###

import plotly.figure_factory as ff

bins= 10000

fig = ff.create_distplot(
    positions, labels, bin_size=bins, show_rug=False)

iplot(fig)
# Out:
# <div>
#
#
#             <div id="eccc35ca-fbcf-4fc3-b70d-bdc5c88b5f33" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("eccc35ca-fbcf-4fc3-b70d-bdc5c88b5f33")) {
#                     Plotly.newPlot(
#                         'eccc35ca-fbcf-4fc3-b70d-bdc5c88b5f33',
#                         [{"autobinx": false, "histnorm": "probability density", "legendgroup": "CAAG", "marker": {"color": "rgb(31, 119, 180)"}, "name": "CAAG", "opacity": 0.7, "type": "histogram", "uid": "b452b8e5-a4bc-4aa6-be0b-2482a10728ac", "x": [3109818, 3112092, 3118644, 3118668, 3120942, 3130324, 3130712, 3130963, 3136844, 3141955, 3160190, 3174431, 3174790, 3176024, 3180381, 3190960, 3200670, 3204767, 3207366, 3213338, 3219053, 3222329, 3224356, 3225733, 3234599, 3239050, 3239810, 3249655, 3254457, 3255236, 3257454, 3264132, 3273930, 3275317, 3300559, 3307988, 3311755, 3315943, 3324616, 3329676, 3339132, 3343452, 3351780, 3352100, 3356225, 3361322, 3368045, 3375425, 3377855, 3389755, 3398595, 3398623, 3401094, 3401233, 3406205, 3412976, 3413435, 3414458, 3414993, 3415313, 3431697, 3435343, 3441333, 3443848, 3446824, 3453730, 3455430, 3457644, 3463289, 3465576, 3469084, 3474100, 3481110, 3486441, 3489855, 3520098, 3529840, 3531933, 3533061, 3546049, 3546073, 3556666, 3558329, 3573916, 3577563, 3582777, 3582962, 3583482, 3587575, 3589962, 3590932, 3594123, 3597590, 3602023, 3607324, 3608243, 3608797, 3615494, 3616176, 3616192, 3617856, 3636887,