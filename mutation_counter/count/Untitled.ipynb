# %%
import os
import errno

from labels import populations
from common import open_infile, get_conserved, get_chromosomes_from_args
from mutation_counter import MutationCounter, IncludedRegion

import gzip
from IPython.display import clear_output
import os
import tempfile

# %%
chrom= 22
chrom = str(chrom)

class IncludedRegion:
    def __init__(self, chrom, output, outfile_path, conserved):
        self.chrom = chrom
        self.output = output
        self.outfile_path = outfile_path
        self.conserved = conserved

        self.conserved_ind = 0

    def configure(self, column_labels):
        self.indices = get_column_indices(column_labels)
        self.column_index_to_population = get_column_index_to_population(column_labels)
        self.mut_count = initialize_mut_count(self.indices)

    def update_position(self, pos):
        while self.conserved_ind<len(self.conserved)-1 and pos>self.conserved[self.conserved_ind][1]:
            self.conserved_ind+=1

    def update_counts(self, position, mutation, population, count):
        if (
            position >= self.conserved[self.conserved_ind][0] and
            position <= self.conserved[self.conserved_ind][1]
        ):
            self.mut_count[(mutation, population, count)] += 1

    def write_output(self):
        write_output(self.output, self.outfile_path, self.indices, self.mut_count)

# %%
included_regions = []

output={population: 'Mut\n' for population in populations}
outfile_path = '../finescale_mut_spectra/mut_type_v_allele_freq_%s_chr'+chrom+'_nosingle.txt'
conserved = [[0, 1e12]]
included_regions.append(IncludedRegion(chrom, output, outfile_path, conserved))


output = {population: 'Ref Alt \n' for population in populations}
outfile_path = '../finescale_mut_spectra/inrepeats_mut_type_v_allele_freq_%s_chr'+chrom+'_nosingle.txt'
conserved = get_conserved('../data/bed_files/nestedRepeats.txt.gz', chrom)
included_regions.append(IncludedRegion(chrom, output, outfile_path, conserved))


output = {population: 'Ref Alt \n' for population in populations}
outfile_path = '../finescale_mut_spectra/phyloP_conserved_mut_type_v_allele_freq_%s_chr'+chrom+'_nosingle.txt'
conserved = get_conserved('../data/bed_files/phastConsElements100way.txt.gz', chrom)
included_regions.append(IncludedRegion(chrom, output, outfile_path, conserved))


mutation_counter = MutationCounter(chrom, included_regions)

# %%
conserved[:10]
# Out:
# [(16055136, 16055172),
#  (16055444, 16055466),
#  (16055553, 16055602),
#  (16063545, 16063572),
#  (16074725, 16074836),
#  (16074882, 16074956),
#  (16074980, 16075098),
#  (16075110, 16075132),
#  (16075175, 16075214),
#  (16075268, 16075296)]

# %% [markdown]
# ### Couting mutations
#
# defining classes

# %%
import itertools as it

def get_human_chimp_differences(chromosome_number):
    human_chimp_differences = {}

    file_path = (
        '../data/hg19_chimp_align/human_chimp_diffs_chr' +
        chromosome_number +
        '.txt'
    )
    

    infile= open(file_path,'r')
    d= 0
    
    for line in infile:
        
        if d > 0 and 'SNP' in line:
            position, _, _, chimp_allele = line.split()
            human_chimp_differences[int(position)] = chimp_allele
        
        d += 1
    
    return human_chimp_differences


def get_column_indices(column_labels):
    population_to_column_indices = {
        population: [] for population in populations
    }
    
    sample_ids = column_labels[9:]
    for i, sample_id in enumerate(sample_ids):
        
        population_to_column_indices[
            sample_id_to_population[sample_id].decode()
        ].append(i + 9)
    
    return population_to_column_indices

# %%
def get_finescale(mutation_counter):
    infile, line = open_infile(mutation_counter.chrom)
    
    print('configuring..')
    mutation_counter.configure(line)
    
    print('processing lines.')
    for line_counter, line in enumerate(infile):
        mutation_counter.process_line(line)
    
    print('writing.')
    mutation_counter.write_output()

    
get_finescale(mutation_counter)

print('finished chrom '.format(chrom))
# Out:
# configuring..
# 	2513 columns
# 	column index to pop
# len of reference seq: 51304566
# 	differences to human
# 	configure regions
# processing lines.
# writing.
# ../finescale_mut_spectra/phyloP_conserved_mut_type_v_allele_freq_%s_chr22_nosingle.txt
# finished chrom

# %%
infile, line = open_infile(mutation_counter.chrom)

# %%
column_labels = line.split()
t= get_column_index_to_population(column_labels)

# %%
t= infile.readline()

# %%
mutation_counter.process_line(t)
# Out:
# [b'22', b'16050075', b'rs587697622', b'A', b'G', b'100', b'PASS', b'AC=1;AF=0.000199681;AN=5008;NS=2504;DP=8012;EAS_AF=0;AMR_AF=0;AFR_AF=0;EUR_AF=0;SAS_AF=0.001;AA=.|||;VT=SNP', b'GT', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', b'0|0', ...

# %%
s=t.strip(b'\n').split(b'\t')
pos=int(s[1])

context = mutation_counter.refseq[pos-2:pos+1]

# %%
s[40].decode()[2]
# Out:
# '|'

# %%
pos in mutation_counter.human_chimp_differences
# Out:
# True

# %%
mutation_counter.human_chimp_differences.get(pos) == s[4]
# Out:
# False

# %%
context
# Out:
# b'CGG'

# %%
s[3] in b'ACGT' and s[4] in b'ACGT'
# Out:
# True

# %%
mutation_counter.column_index_to_population
# Out:
# {9: b'GBR',
#  10: b'GBR',
#  11: b'GBR',
#  12: b'GBR',
#  13: b'GBR',
#  14: b'GBR',
#  15: b'GBR',
#  16: b'GBR',
#  17: b'GBR',
#  18: b'GBR',
#  19: b'GBR',
#  20: b'GBR',
#  21: b'GBR',
#  22: b'GBR',
#  23: b'GBR',
#  24: b'GBR',
#  25: b'GBR',
#  26: b'GBR',
#  27: b'GBR',
#  28: b'GBR',
#  29: b'GBR',
#  30: b'GBR',
#  31: b'GBR',
#  32: b'GBR',
#  33: b'GBR',
#  34: b'GBR',
#  35: b'GBR',
#  36: b'GBR',
#  37: b'GBR',
#  38: b'GBR',
#  39: b'GBR',
#  40: b'GBR',
#  41: b'GBR',
#  42: b'GBR',
#  43: b'GBR',
#  44: b'GBR',
#  45: b'GBR',
#  46: b'GBR',
#  47: b'GBR',
#  48: b'GBR',
#  49: b'GBR',
#  50: b'GBR',
#  51: b'GBR',
#  52: b'GBR',
#  53: b'GBR',
#  54: b'GBR',
#  55: b'GBR',
#  56: b'GBR',
#  57: b'GBR',
#  58: b'GBR',
#  59: b'GBR',
#  60: b'GBR',
#  61: b'GBR',
#  62: b'GBR',
#  63: b'GBR',
#  64: b'FIN',
#  65: b'FIN',
#  66: b'FIN',
#  67: b'FIN',
#  68: b'FIN',
#  69: b'FIN',
#  70: b'FIN',
#  71: b'FIN',
#  72: b'FIN',
#  73: b'FIN',
#  74: b'FIN',
#  75: b'FIN',
#  76: b'FIN',
#  77: b'FIN',
#  78: b'FIN',
#  79: b'FIN',
#  80: b'FIN',
#  81: b'GBR',
#  82: b'GBR',
#  83: b'GBR',
#  84: b'GBR',
#  85: b'GBR',
#  86: b'GBR',
#  87: b'GBR',
#  88: b'GBR',
#  89: b'GBR',
#  90: b'GBR',
#  91: b'GBR',
#  92: b'GBR',
#  93: b'GBR',
#  94: b'GBR',
#  95: b'GBR',
#  96: b'GBR',
#  97: b'GBR',
#  98: b'GBR',
#  99: b'GBR',
#  100: b'GBR',
#  101: b'GBR',
#  102: b'GBR',
#  103: b'GBR',
#  104: b'GBR',
#  105: b'GBR',
#  106: b'GBR',
#  107: b'GBR',
#  108: b'GBR',
#  109: b'GBR',
#  110: b'GBR',
#  111: b'GBR',
#  112: b'FIN',
#  113: b'FIN',
#  114: b'FIN',
#  115: b'FIN',
#  116: b'FIN',
#  117: b'FIN',
#  118: b'FIN',
#  119: b'FIN',
#  120: b'FIN',
#  121: b'FIN',
#  122: b'FIN',
#  123: b'FIN',
#  124: b'FIN',
#  125: b'FIN',
#  126: b'FIN',
#  127: b'FIN',
#  128: b'FIN',
#  129: b'FIN',
#  130: b'FIN',
#  131: b'FIN',
#  132: b'FIN',
#  133: b'FIN',
#  134: b'FIN',
#  135: b'FIN',
#  136: b'FIN',
#  137: b'FIN',
#  138: b'FIN',
#  139: b'FIN',
#  140: b'FIN',
#  141: b'FIN',
#  142: b'FIN',
#  143: b'FIN',
#  144: b'FIN',
#  145: b'FIN',
#  146: b'FIN',
#  147: b'FIN',
#  148: b'FIN',
#  149: b'FIN',
#  150: b'FIN',
#  151: b'FIN',
#  152: b'FIN',
#  153: b'FIN',
#  154: b'FIN',
#  155: b'FIN',
#  156: b'FIN',
#  157: b'FIN',
#  158: b'FIN',
#  159: b'FIN',
#  160: b'FIN',
#  161: b'FIN',
#  162: b'FIN',
#  163: b'FIN',
#  164: b'FIN',
#  165: b'FIN',
#  166: b'FIN',
#  167: b'FIN',
#  168: b'FIN',
#  169: b'FIN',
#  170: b'FIN',
#  171: b'FIN',
#  172: b'FIN',
#  173: b'FIN',
#  174: b'FIN',
#  175: b'FIN',
#  176: b'FIN',
#  177: b'FIN',
#  178: b'FIN',
#  179: b'FIN',
#  180: b'FIN',
#  181: b'FIN',
#  182: b'FIN',
#  183: b'FIN',
#  184: b'FIN',
#  185: b'FIN',
#  186: b'FIN',
#  187: b'FIN',
#  188: b'FIN',
#  189: b'FIN',
#  190: b'FIN',
#  191: b'FIN',
#  192: b'FIN',
#  193: b'FIN',
#  194: b'CHS',
#  195: b'CHS',
#  196: b'CHS',
#  197: b'CHS',
#  198: b'CHS',
#  199: b'CHS',
#  200: b'CHS',
#  201: b'CHS',
#  202: b'CHS',
#  203: b'CHS',
#  204: b'CHS',
#  205: b'CHS',
#  206: b'CHS',
#  207: b'CHS',
#  208: b'CHS',
#  209: b'CHS',
#  210: b'CHS',
#  211: b'CHS',
#  212: b'CHS',
#  213: b'CHS',
#  214: b'CHS',
#  215: b'CHS',
#  216: b'CHS',
#  217: b'CHS',
#  218: b'CHS',
#  219: b'CHS',
#  220: b'CHS',
#  221: b'CHS',
#  222: b'CHS',
#  223: b'CHS',
#  224: b'CHS',
#  225: b'CHS',
#  226: b'CHS',
#  227: b'CHS',
#  228: b'CHS',
#  229: b'CHS',
#  230: b'CHS',
#  231: b'CHS',
#  232: b'CHS',
#  233: b'CHS',
#  234: b'CHS',
#  235: b'CHS',
#  236: b'PUR',
#  237: b'PUR',
#  238: b'PUR',
#  239: b'CHS',
#  240: b'CHS',
#  241: b'CHS',
#  242: b'CHS',
#  243: b'CHS',
#  244: b'CHS',
#  245: b'CHS',
#  246: b'CHS',
#  247: b'CHS',
#  248: b'CHS',
#  249: b'CHS',
#  250: b'CHS',
#  251: b'CHS',
#  252: b'CHS',
#  253: b'CHS',
#  254: b'CHS',
#  255: b'CHS',
#  256: b'CHS',
#  257: b'CHS',
#  258: b'CHS',
#  259: b'CHS',
#  260: b'CHS',
#  261: b'CHS',
#  262: b'CHS',
#  263: b'CHS',
#  264: b'CHS',
#  265: b'CHS',
#  266: b'CHS',
#  267: b'CHS',
#  268: b'CHS',
#  269: b'CHS',
#  270: b'CHS',
#  271: b'CHS',
#  272: b'CHS',
#  273: b'CHS',
#  274: b'PUR',
#  275: b'PUR',
#  276: b'PUR',
#  277: b'PUR',
#  278: b'CHS',
#  279: b'CHS',
#  280: b'CHS',
#  281: b'CHS',
#  282: b'CHS',
#  283: b'CHS',
#  284: b'CHS',
#  285: b'CHS',
#  286: b'CHS',
#  287: b'CHS',
#  288: b'CHS',
#  289: b'CHS',
#  290: b'CHS',
#  291: b'CHS',
#  292: b'CHS',
#  293: b'CHS',
#  294: b'CHS',
#  295: b'CHS',
#  296: b'CHS',
#  297: b'CHS',
#  298: b'CHS',
#  299: b'CHS',
#  300: b'CHS',
#  301: b'CHS',
#  302: b'CHS',
#  303: b'CHS',
#  304: b'CHS',
#  305: b'CHS',
#  306: b'PUR',
#  307: b'PUR',
#  308: b'PUR',
#  309: b'PUR',
#  310: b'PUR',
#  311: b'PUR',
#  312: b'PUR',
#  313: b'PUR',
#  314: b'PUR',
#  315: b'CDX',
#  316: b'CDX',
#  317: b'CDX',
#  318: b'CDX',
#  319: b'CDX',
#  320: b'CDX',
#  321: b'CDX',
#  322: b'CDX',
#  323: b'CDX',
#  324: b'CDX',
#  325: b'CDX',
#  326: b'CDX',
#  327: b'CDX',
#  328: b'CDX',
#  329: b'CDX',
#  330: b'PUR',
#  331: b'PUR',
#  332: b'PUR',
#  333: b'PUR',
#  334: b'PUR',
#  335: b'PUR',
#  336: b'PUR',
#  337: b'PUR',
#  338: b'PUR',
#  339: b'PUR',
#  340: b'PUR',
#  341: b'PUR',
#  342: b'PUR',
#  343: b'PUR',
#  344: b'PUR',
#  345: b'PUR',
#  346: b'PUR',
#  347: b'PUR',
#  348: b'PUR',
#  349: b'PUR',
#  350: b'PUR',
#  351: b'PUR',
#  352: b'PUR',
#  353: b'PUR',
#  354: b'PUR',
#  355: b'PUR',
#  356: b'PUR',
#  357: b'PUR',
#  358: b'PUR',
#  359: b'PUR',
#  360: b'PUR',
#  361: b'PUR',
#  362: b'PUR',
#  363: b'PUR',
#  364: b'PUR',
#  365: b'PUR',
#  366: b'PUR',
#  367: b'PUR',
#  368: b'PUR',
#  369: b'PUR',
#  370: b'PUR',
#  371: b'CLM',
#  372: b'CLM',
#  373: b'CLM',
#  374: b'CLM',
#  375: b'CLM',
#  376: b'CLM',
#  377: b'CLM',
#  378: b'CLM',
#  379: b'CLM',
#  380: b'CLM',
#  381: b'CLM',
#  382: b'CLM',
#  383: b'CLM',
#  384: b'CLM',
#  385: b'CLM',
#  386: b'CLM',
#  387: b'CLM',
#  388: b'CLM',
#  389: b'PUR',
#  390: b'PUR',
#  391: b'PUR',
#  392: b'PUR',
#  393: b'PUR',
#  394: b'PUR',
#  395: b'PUR',
#  396: b'PUR',
#  397: b'PUR',
#  398: b'PUR',
#  399: b'PUR',
#  400: b'PUR',
#  401: b'PUR',
#  402: b'PUR',
#  403: b'PUR',
#  404: b'PUR',
#  405: b'PUR',
#  406: b'PUR',
#  407: b'PUR',
#  408: b'PUR',
#  409: b'PUR',
#  410: b'PUR',
#  411: b'PUR',
#  412: b'PUR',
#  413: b'PUR',
#  414: b'PUR',
#  415: b'CLM',
#  416: b'CLM',
#  417: b'CLM',
#  418: b'CLM',
#  419: b'CLM',
#  420: b'CLM',
#  421: b'CLM',
#  422: b'CLM',
#  423: b'CLM',
#  424: b'CLM',
#  425: b'CLM',
#  426: b'CLM',
#  427: b'CLM',
#  428: b'CLM',
#  429: b'CLM',
#  430: b'CLM',
#  431: b'PUR',
#  432: b'PUR',
#  433: b'PUR',
#  434: b'PUR',
#  435: b'PUR',
#  436: b'PUR',
#  437: b'PUR',
#  438: b'PUR',
#  439: b'PUR',
#  440: b'PUR',
#  441: b'GBR',
#  442: b'CLM',
#  443: b'CLM',
#  444: b'CLM',
#  445: b'CLM',
#  446: b'CLM',
#  447: b'CLM',
#  448: b'CLM',
#  449: b'CLM',
#  450: b'CLM',
#  451: b'CLM',
#  452: b'CLM',
#  453: b'CLM',
#  454: b'CLM',
#  455: b'CLM',
#  456: b'CLM',
#  457: b'CLM',
#  458: b'CLM',
#  459: b'CLM',
#  460: b'CLM',
#  461: b'CLM',
#  462: b'CLM',
#  463: b'CLM',
#  464: b'CLM',
#  465: b'CLM',
#  466: b'CLM',
#  467: b'CLM',
#  468: b'CLM',
#  469: b'PUR',
#  470: b'PUR',
#  471: b'PUR',
#  472: b'PUR',
#  473: b'PUR',
#  474: b'PUR',
#  475: b'PUR',
#  476: b'PUR',
#  477: b'PUR',
#  478: b'PUR',
#  479: b'PUR',
#  480: b'CLM',
#  481: b'CLM',
#  482: b'CLM',
#  483: b'CLM',
#  484: b'CLM',
#  485: b'CLM',
#  486: b'CLM',
#  487: b'CLM',
#  488: b'CLM',
#  489: b'CLM',
#  490: b'CLM',
#  491: b'CLM',
#  492: b'CLM',
#  493: b'CLM',
#  494: b'CLM',
#  495: b'CLM',
#  496: b'CLM',
#  497: b'CLM',
#  498: b'CLM',
#  499: b'CLM',
#  500: b'CLM',
#  501: b'CLM',
#  502: b'CLM',
#  503: b'CLM',
#  504: b'CLM',
#  505: b'CLM',
#  506: b'CLM',
#  507: b'CLM',
#  508: b'CLM',
#  509: b'CLM',
#  510: b'IBS',
#  511: b'IBS',
#  512: b'IBS',
#  513: b'IBS',
#  514: b'IBS',
#  515: b'IBS',
#  516: b'IBS',
#  517: b'IBS',
#  518: b'IBS',
#  519: b'IBS',
#  520: b'IBS',
#  521: b'IBS',
#  522: b'IBS',
#  523: b'IBS',
#  524: b'IBS',
#  525: b'IBS',
#  526: b'IBS',
#  527: b'IBS',
#  528: b'IBS',
#  529: b'IBS',
#  530: b'IBS',
#  531: b'IBS',
#  532: b'IBS',
#  533: b'IBS',
#  534: b'CLM',
#  535: b'CLM',
#  536: b'CLM',
#  537: b'PEL',
#  538: b'PEL',
#  539: b'PEL',
#  540: b'PEL',
#  541: b'PEL',
#  542: b'PEL',
#  543: b'PJL',
#  544: b'PJL',
#  545: b'PJL',
#  546: b'PJL',
#  547: b'KHV',
#  548: b'KHV',
#  549: b'KHV',
#  550: b'KHV',
#  551: b'KHV',
#  552: b'KHV',
#  553: b'IBS',
#  554: b'IBS',
#  555: b'IBS',
#  556: b'IBS',
#  557: b'IBS',
#  558: b'IBS',
#  559: b'IBS',
#  560: b'IBS',
#  561: b'IBS',
#  562: b'IBS',
#  563: b'IBS',
#  564: b'IBS',
#  565: b'IBS',
#  566: b'IBS',
#  567: b'IBS',
#  568: b'IBS',
#  569: b'IBS',
#  570: b'IBS',
#  571: b'IBS',
#  572: b'IBS',
#  573: b'IBS',
#  574: b'IBS',
#  575: b'IBS',
#  576: b'IBS',
#  577: b'IBS',
#  578: b'IBS',
#  579: b'IBS',
#  580: b'IBS',
#  581: b'IBS',
#  582: b'IBS',
#  583: b'IBS',
#  584: b'IBS',
#  585: b'IBS',
#  586: b'IBS',
#  587: b'IBS',
#  588: b'IBS',
#  589: b'IBS',
#  590: b'IBS',
#  591: b'IBS',
#  592: b'IBS',
#  593: b'IBS',
#  594: b'IBS',
#  595: b'IBS',
#  596: b'IBS',
#  597: b'IBS',
#  598: b'IBS',
#  599: b'IBS',
#  600: b'IBS',
#  601: b'IBS',
#  602: b'IBS',
#  603: b'IBS',
#  604: b'IBS',
#  605: b'IBS',
#  606: b'IBS',
#  607: b'IBS',
#  608: b'IBS',
#  609: b'IBS',
#  610: b'IBS',
#  611: b'IBS',
#  612: b'IBS',
#  613: b'IBS',
#  614: b'IBS',
#  615: b'IBS',
#  616: b'IBS',
#  617: b'IBS',
#  618: b'IBS',
#  619: b'IBS',
#  620: b'IBS',
#  621: b'IBS',
#  622: b'IBS',
#  623: b'GBR',
#  624: b'GBR',
#  625: b'GBR',
#  626: b'CDX',
#  627: b'CDX',
#  628: b'CDX',
#  629: b'CDX',
#  630: b'CDX',
#  631: b'CDX',
#  632: b'CDX',
#  633: b'CDX',
#  634: b'CDX',
#  635: b'CDX',
#  636: b'CDX',
#  637: b'CDX',
#  638: b'CDX',
#  639: b'CDX',
#  640: b'CDX',
#  641: b'CDX',
#  642: b'CDX',
#  643: b'CDX',
#  644: b'CDX',
#  645: b'CDX',
#  646: b'CDX',
#  647: b'CDX',
#  648: b'KHV',
#  649: b'KHV',
#  650: b'KHV',
#  651: b'KHV',
#  652: b'KHV',
#  653: b'KHV',
#  654: b'KHV',
#  655: b'KHV',
#  656: b'KHV',
#  657: b'KHV',
#  658: b'KHV',
#  659: b'KHV',
#  660: b'KHV',
#  661: b'KHV',
#  662: b'KHV',
#  663: b'KHV',
#  664: b'KHV',
#  665: b'KHV',
#  666: b'KHV',
#  667: b'KHV',
#  668: b'KHV',
#  669: b'KHV',
#  670: b'KHV',
#  671: b'KHV',
#  672: b'KHV',
#  673: b'KHV',
#  674: b'KHV',
#  675: b'KHV',
#  676: b'KHV',
#  677: b'KHV',
#  678: b'KHV',
#  679: b'KHV',
#  680: b'KHV',
#  681: b'KHV',
#  682: b'ACB',
#  683: b'ACB',
#  684: b'ACB',
#  685: b'ACB',
#  686: b'ACB',
#  687: b'ACB',
#  688: b'ACB',
#  689: b'ACB',
#  690: b'PEL',
#  691: b'PEL',
#  692: b'ACB',
#  693: b'ACB',
#  694: b'ACB',
#  695: b'ACB',
#  696: b'ACB',
#  697: b'PEL',
#  698: b'PEL',
#  699: b'PEL',
#  700: b'PEL',
#  701: b'PEL',
#  702: b'PEL',
#  703: b'PEL',
#  704: b'PEL',
#  705: b'PEL',
#  706: b'PEL',
#  707: b'PEL',
#  708: b'PEL',
#  709: b'PEL',
#  710: b'PEL',
#  711: b'PEL',
#  712: b'PEL',
#  713: b'PEL',
#  714: b'PEL',
#  715: b'PEL',
#  716: b'PEL',
#  717: b'PEL',
#  718: b'PEL',
#  719: b'PEL',
#  720: b'PEL',
#  721: b'ACB',
#  722: b'ACB',
#  723: b'PEL',
#  724: b'PEL',
#  725: b'PEL',
#  726: b'PEL',
#  727: b'PEL',
#  728: b'PEL',
#  729: b'PEL',
#  730: b'PEL',
#  731: b'PEL',
#  732: b'PEL',
#  733: b'PEL',
#  734: b'PEL',
#  735: b'PEL',
#  736: b'ACB',
#  737: b'ACB',
#  738: b'ACB',
#  739: b'ACB',
#  740: b'ACB',
#  741: b'PEL',
#  742: b'PEL',
#  743: b'PEL',
#  744: b'PEL',
#  745: b'PEL',
#  746: b'PEL',
#  747: b'PEL',
#  748: b'ACB',
#  749: b'ACB',
#  750: b'ACB',
#  751: b'ACB',
#  752: b'ACB',
#  753: b'KHV',
#  754: b'KHV',
#  755: b'KHV',
#  756: b'KHV',
#  757: b'KHV',
#  758: b'KHV',
#  759: b'KHV',
#  760: b'KHV',
#  761: b'KHV',
#  762: b'KHV',
#  763: b'KHV',
#  764: b'KHV',
#  765: b'KHV',
#  766: b'KHV',
#  767: b'KHV',
#  768: b'KHV',
#  769: b'KHV',
#  770: b'ACB',
#  771: b'ACB',
#  772: b'ACB',
#  773: b'ACB',
#  774: b'KHV',
#  775: b'KHV',
#  776: b'KHV',
#  777: b'KHV',
#  778: b'KHV',
#  779: b'KHV',
#  780: b'KHV',
#  781: b'KHV',
#  782: b'KHV',
#  783: b'KHV',
#  784: b'KHV',
#  785: b'KHV',
#  786: b'KHV',
#  787: b'KHV',
#  788: b'KHV',
#  789: b'KHV',
#  790: b'KHV',
#  791: b'KHV',
#  792: b'KHV',
#  793: b'KHV',
#  794: b'KHV',
#  795: b'PEL',
#  796: b'PEL',
#  797: b'ACB',
#  798: b'PEL',
#  799: b'PEL',
#  800: b'PEL',
#  801: b'ACB',
#  802: b'ACB',
#  803: b'ACB',
#  804: b'KHV',
#  805: b'KHV',
#  806: b'KHV',
#  807: b'KHV',
#  808: b'KHV',
#  809: b'KHV',
#  810: b'KHV',
#  811: b'KHV',
#  812: b'KHV',
#  813: b'KHV',
#  814: b'KHV',
#  815: b'KHV',
#  816: b'KHV',
#  817: b'KHV',
#  818: b'KHV',
#  819: b'KHV',
#  820: b'KHV',
#  821: b'ACB',
#  822: b'ACB',
#  823: b'PEL',
#  824: b'PEL',
#  825: b'PEL',
#  826: b'CDX',
#  827: b'CDX',
#  828: b'CDX',
#  829: b'CDX',
#  830: b'CDX',
#  831: b'CDX',
#  832: b'CDX',
#  833: b'CDX',
#  834: b'CDX',
#  835: b'CDX',
#  836: b'CDX',
#  837: b'CDX',
#  838: b'CDX',
#  839: b'CDX',
#  840: b'CDX',
#  841: b'CDX',
#  842: b'CDX',
#  843: b'CDX',
#  844: b'CDX',
#  845: b'CDX',
#  846: b'GBR',
#  847: b'IBS',
#  848: b'IBS',
#  849: b'IBS',
#  850: b'IBS',
#  851: b'IBS',
#  852: b'IBS',
#  853: b'IBS',
#  854: b'IBS',
#  855: b'IBS',
#  856: b'IBS',
#  857: b'IBS',
#  858: b'IBS',
#  859: b'IBS',
#  860: b'CDX',
#  861: b'PEL',
#  862: b'PEL',
#  863: b'ACB',
#  864: b'ACB',
#  865: b'PEL',
#  866: b'PEL',
#  867: b'PEL',
#  868: b'PEL',
#  869: b'PEL',
#  870: b'PEL',
#  871: b'PEL',
#  872: b'PEL',
#  873: b'PEL',
#  874: b'PEL',
#  875: b'PEL',
#  876: b'ACB',
#  877: b'ACB',
#  878: b'ACB',
#  879: b'ACB',
#  880: b'PEL',
#  881: b'PEL',
#  882: b'PEL',
#  883: b'PEL',
#  884: b'PEL',
#  885: b'PEL',
#  886: b'PEL',
#  887: b'PEL',
#  888: b'ACB',
#  889: b'ACB',
#  890: b'ACB',
#  891: b'PEL',
#  892: b'ACB',
#  893: b'ACB',
#  894: b'ACB',
#  895: b'ACB',
#  896: b'ACB',
#  897: b'ACB',
#  898: b'ACB',
#  899: b'ACB',
#  900: b'ACB',
#  901: b'ACB',
#  902: b'ACB',
#  903: b'ACB',
#  904: b'ACB',
#  905: b'PEL',
#  906: b'PEL',
#  907: b'CDX',
#  908: b'CDX',
#  909: b'CDX',
#  910: b'CDX',
#  911: b'CDX',
#  912: b'CDX',
#  913: b'CDX',
#  914: b'CDX',
#  915: b'CDX',
#  916: b'CDX',
#  917: b'CDX',
#  918: b'CDX',
#  919: b'CDX',
#  920: b'CDX',
#  921: b'CDX',
#  922: b'CDX',
#  923: b'CDX',
#  924: b'CDX',
#  925: b'CDX',
#  926: b'CDX',
#  927: b'CDX',
#  928: b'CDX',
#  929: b'CDX',
#  930: b'CDX',
#  931: b'CDX',
#  932: b'CDX',
#  933: b'CDX',
#  934: b'CDX',
#  935: b'CDX',
#  936: b'CDX',
#  937: b'CDX',
#  938: b'CDX',
#  939: b'CDX',
#  940: b'CDX',
#  941: b'CDX',
#  942: b'ACB',
#  943: b'ACB',
#  944: b'PEL',
#  945: b'ACB',
#  946: b'ACB',
#  947: b'ACB',
#  948: b'ACB',
#  949: b'ACB',
#  950: b'ACB',
#  951: b'ACB',
#  952: b'ACB',
#  953: b'ACB',
#  954: b'GWD',
#  955: b'GWD',
#  956: b'GWD',
#  957: b'GWD',
#  958: b'ACB',
#  959: b'ACB',
#  960: b'ACB',
#  961: b'ACB',
#  962: b'ACB',
#  963: b'ACB',
#  964: b'ACB',
#  965: b'ACB',
#  966: b'ACB',
#  967: b'PJL',
#  968: b'PJL',
#  969: b'PJL',
#  970: b'PJL',
#  971: b'ACB',
#  972: b'ACB',
#  973: b'ACB',
#  974: b'ACB',
#  975: b'ACB',
#  976: b'ACB',
#  977: b'ACB',
#  978: b'KHV',
#  979: b'KHV',
#  980: b'KHV',
#  981: b'KHV',
#  982: b'ACB',
#  983: b'ACB',
#  984: b'ACB',
#  985: b'ACB',
#  986: b'ACB',
#  987: b'ACB',
#  988: b'ACB',
#  989: b'ACB',
#  990: b'ACB',
#  991: b'ACB',
#  992: b'GWD',
#  993: b'GWD',
#  994: b'GWD',
#  995: b'GWD',
#  996: b'GWD',
#  997: b'GWD',
#  998: b'GWD',
#  999: b'ACB',
#  1000: b'ACB',
#  1001: b'GWD',
#  1002: b'GWD',
#  1003: b'GWD',
#  1004: b'GWD',
#  1005: b'GWD',
#  1006: b'GWD',
#  1007: b'GWD',
#  1008: b'GWD',
#  ...}
